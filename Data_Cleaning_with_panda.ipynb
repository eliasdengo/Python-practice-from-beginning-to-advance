# %% [markdown]
# <a href="https://colab.research.google.com/github/eliasdengo/Python-practice-from-beginning-to-advance/blob/Eliasrepos/Data_Cleaning_with_panda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/sample_data/Airbnb_Open_Data.csv')
# Out:
# /tmp/ipython-input-3261105143.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('/content/sample_data/Airbnb_Open_Data.csv')

# %%
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %% [markdown]
# Check for Missing Values,
# Remove Duplicates,
# Data Type Conversion,
# Handle Outliers,
# Standardize and Normalize Data,
# Encoding Categorical Variables,
# Adjust Formatting Consistency,
# Feature Engineering,
# Reindexing the DataFrame,
# Final Review

# %%
df.describe()
# Out:
#                  id       host id            lat           long  \
# count  1.025990e+05  1.025990e+05  102591.000000  102591.000000
# mean   2.914623e+07  4.925411e+10      40.728094     -73.949644
# std    1.625751e+07  2.853900e+10       0.055857       0.049521
# min    1.001254e+06  1.236005e+08      40.499790     -74.249840
# 25%    1.508581e+07  2.458333e+10      40.688740     -73.982580
# 50%    2.913660e+07  4.911774e+10      40.722290     -73.954440
# 75%    4.320120e+07  7.399650e+10      40.762760     -73.932350
# max    5.736742e+07  9.876313e+10      40.916970     -73.705220
#
#        Construction year  minimum nights  number of reviews  \
# count      102385.000000   102190.000000      102416.000000
# mean         2012.487464        8.135845          27.483743
# std             5.765556       30.553781          49.508954
# min          2003.000000    -1223.000000           0.000000
# 25%          2007.000000        2.000000           1.000000
# ...

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
column_to_keep=['NAME', 'host id', 'host_identity_verified', 'host name',
       'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
       'country code', 'instant_bookable', 'cancellation_policy', 'room type',
       'Construction year', 'price', 'service fee', 'minimum nights',
       'number of reviews', 'last review']

# %%
column_to_drop=['reviews per month',
       'review rate number', 'calculated host listings count',
       'availability 365', 'house_rules', 'license','id']

# %%
len(column_to_drop)
# Out:
# 7

# %%
len(column_to_keep)
# Out:
# 19

# %% [markdown]
# 1st filter the data

# %%
df[column_to_keep]
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
df.shape
# Out:
# (102599, 26)

# %% [markdown]
# 2nd droping columns

# %%
df.drop(columns=column_to_drop,inplace=True)

# %%
df.shape
# Out:
# (102599, 19)

# %%
#rename
df.rename(columns={'NAME':'Name'},inplace=True)

# %%
df
# Out:
#                                                     Name      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
# new column name
new_column_name=[]
for i in df.columns:
  new_column_name.append(i.upper())
df.columns=new_column_name

# %%
df.columns
# Out:
# Index(['NAME', 'HOST ID', 'HOST_IDENTITY_VERIFIED', 'HOST NAME',
#        'NEIGHBOURHOOD GROUP', 'NEIGHBOURHOOD', 'LAT', 'LONG', 'COUNTRY',
#        'COUNTRY CODE', 'INSTANT_BOOKABLE', 'CANCELLATION_POLICY', 'ROOM TYPE',
#        'CONSTRUCTION YEAR', 'PRICE', 'SERVICE FEE', 'MINIMUM NIGHTS',
#        'NUMBER OF REVIEWS', 'LAST REVIEW'],
#       dtype='object')

# %%
df
# Out:
#                                                     NAME      HOST ID  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        HOST_IDENTITY_VERIFIED    HOST NAME NEIGHBOURHOOD GROUP  \
# ...

# %% [markdown]
# # duplicated data

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# is null value

# %%
data.to_excel('cleaned_excel_data.xlsx',index=False)

# %%
df.isna().sum()
# Out:
# NAME                        250
# HOST ID                       0
# HOST_IDENTITY_VERIFIED      289
# HOST NAME                   404
# NEIGHBOURHOOD GROUP          29
# NEIGHBOURHOOD                16
# LAT                           8
# LONG                          8
# COUNTRY                     532
# COUNTRY CODE                131
# INSTANT_BOOKABLE            105
# CANCELLATION_POLICY          76
# ROOM TYPE                     0
# CONSTRUCTION YEAR           214
# PRICE                       247
# SERVICE FEE                 273
# MINIMUM NIGHTS              400
# NUMBER OF REVIEWS           183
# LAST REVIEW               15832
# dtype: int64

# %%
df.drop(columns='LAST REVIEW',inplace=True)

# %%
df
# Out:
#                                                     NAME      HOST ID  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102053               Cozy bright room near Prospect Park  77326652202
# 102054         Private Bedroom with Amazing Rooftop View  45936254757
# 102055     Pretty Brooklyn One-Bedroom for 2 to 4 people  23801060917
# 102056        Room & private bathroom in historic Harlem  15593031571
# 102057                                   Rosalee Stewart  93578954226
#
#        HOST_IDENTITY_VERIFIED HOST NAME NEIGHBOURHOOD GROUP  \
# 0                 unconfirmed  Madaline            Brooklyn
# ...

# %%
df.isna().sum()
# Out:
# NAME                      250
# HOST ID                     0
# HOST_IDENTITY_VERIFIED    289
# HOST NAME                 404
# NEIGHBOURHOOD GROUP        29
# NEIGHBOURHOOD              16
# LAT                         8
# LONG                        8
# COUNTRY                   532
# COUNTRY CODE              131
# INSTANT_BOOKABLE          105
# CANCELLATION_POLICY        76
# ROOM TYPE                   0
# CONSTRUCTION YEAR         214
# PRICE                     247
# SERVICE FEE               273
# MINIMUM NIGHTS            400
# NUMBER OF REVIEWS         183
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# NAME                      0
# HOST ID                   0
# HOST_IDENTITY_VERIFIED    0
# HOST NAME                 0
# NEIGHBOURHOOD GROUP       0
# NEIGHBOURHOOD             0
# LAT                       0
# LONG                      0
# COUNTRY                   0
# COUNTRY CODE              0
# INSTANT_BOOKABLE          0
# CANCELLATION_POLICY       0
# ROOM TYPE                 0
# CONSTRUCTION YEAR         0
# PRICE                     0
# SERVICE FEE               0
# MINIMUM NIGHTS            0
# NUMBER OF REVIEWS         0
# dtype: int64

# %%
df['HOST_IDENTITY_VERIFIED']=df['HOST_IDENTITY_VERIFIED'].str.upper()

# %%
df
# Out:
#                                                     NAME      HOST ID  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102029            Cozy room in a 2B with backyard access   5155155913
# 102030                      An East Williamsburg Delight  71564706996
# 102031                      Cozy bedroom in williamsburg  83101851929
# 102032                            Spacious Room w/ 2 Bed  69037598918
# 102040                     Room in Queens, NY, near LGA.  56457739998
#
#        HOST_IDENTITY_VERIFIED  HOST NAME NEIGHBOURHOOD GROUP  \
# 0                 UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
df['INSTANT_BOOKABLE']=df['INSTANT_BOOKABLE'].apply(lambda x:1 if x==True else 0)

# %%
df
# Out:
#                                                     NAME      HOST ID  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102029            Cozy room in a 2B with backyard access   5155155913
# 102030                      An East Williamsburg Delight  71564706996
# 102031                      Cozy bedroom in williamsburg  83101851929
# 102032                            Spacious Room w/ 2 Bed  69037598918
# 102040                     Room in Queens, NY, near LGA.  56457739998
#
#        HOST_IDENTITY_VERIFIED  HOST NAME NEIGHBOURHOOD GROUP  \
# 0                 UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
df['INSTANT_BOOKABLE']
# Out:
# 0         0
# 1         0
# 4         0
# 5         1
# 7         0
#          ..
# 102029    0
# 102030    1
# 102031    1
# 102032    0
# 102040    1
# Name: INSTANT_BOOKABLE, Length: 99342, dtype: int64

# %%
df['PRICE']
# Out:
# 0           $966
# 1           $142
# 4           $204
# 5           $577
# 7         $1,060
#            ...
# 102029      $822
# 102030      $455
# 102031    $1,078
# 102032      $103
# 102040      $982
# Name: PRICE, Length: 99342, dtype: object

# %%
df['PRICE']=df['PRICE'].str.replace('$','')

# %%
df['PRICE']
# Out:
# 0           966
# 1           142
# 4           204
# 5           577
# 7         1,060
#            ...
# 102029      822
# 102030      455
# 102031    1,078
# 102032      103
# 102040      982
# Name: PRICE, Length: 99342, dtype: object

# %%
df['PRICE']=df['PRICE'].str.replace(',','')

# %%
df['PRICE']
# Out:
# 0          966
# 1          142
# 4          204
# 5          577
# 7         1060
#           ...
# 102029     822
# 102030     455
# 102031    1078
# 102032     103
# 102040     982
# Name: PRICE, Length: 99342, dtype: object

# %%
df['PRICE']=df['PRICE'].str.replace(' ','')

# %%
df['PRICE']=df['PRICE'].astype(int)

# %%
type(df['PRICE'][1])
# Out:
# numpy.int64

# %%
df.head(100)
# Out:
#                                                  NAME      HOST ID  \
# 0                  Clean & quiet apt home by the park  80014485718
# 1                               Skylit Midtown Castle  52335172823
# 4    Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5           Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                     BlissArtsSpace!  90821839709
# ..                                                ...          ...
# 232   Artistic, Cozy, and Spacious w/ Patio! Sleeps 5  14920488865
# 237                  City Room - Private Luxury Suite  34228394206
# 243                                 Huge Chelsea Loft  27743402115
# 244                      Great room in great location  27437089550
# 245          Exclusive Room with Private Bath in  LES   6670990373
#
#     HOST_IDENTITY_VERIFIED HOST NAME NEIGHBOURHOOD GROUP       NEIGHBOURHOOD  \
# 0              UNCONFIRMED  Madaline            Brooklyn          Kensington
# ...

# %%
df.to_csv('cleared_data',index=False)

# %%
data=pd.read_csv('/content/cleared_data')

# %%
data.head()
# Out:
#                                                NAME      HOST ID  \
# 0                Clean & quiet apt home by the park  80014485718
# 1                             Skylit Midtown Castle  52335172823
# 2  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4                                   BlissArtsSpace!  90821839709
#
#   HOST_IDENTITY_VERIFIED HOST NAME NEIGHBOURHOOD GROUP       NEIGHBOURHOOD  \
# 0            UNCONFIRMED  Madaline            Brooklyn          Kensington
# 1               VERIFIED     Jenna           Manhattan             Midtown
# 2               VERIFIED    Lyndon           Manhattan         East Harlem
# 3               VERIFIED  Michelle           Manhattan         Murray Hill
# 4            UNCONFIRMED      Emma            Brooklyn  Bedford-Stuyvesant
#
#         LAT      LONG        COUNTRY COUNTRY CODE  INSTANT_BOOKABLE  \
# ...
